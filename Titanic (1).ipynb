# %%
 import pandas as pd

# %%
titanic = pd.read_csv("train.csv")

# %%
titanic.shape
# Out:
# (891, 12)

# %%
test = pd.read_csv("test.csv")
test.shape
# Out:
# (418, 11)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
ports = pd.get_dummies(titanic.Embarked,prefix="Embarked")
ports.head()
# Out:
#    Embarked_C  Embarked_Q  Embarked_S
# 0       False       False        True
# 1        True       False       False
# 2       False       False        True
# 3       False       False        True
# 4       False       False        True

# %%
titanic = titanic.join(ports)
titanic.drop(["Embarked_"],axis = 1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-e625e870c693> in <cell line: 1>()
# ----> 1 titanic = titanic.join(ports)
#       2 titanic.drop(["Embarked_"],axis = 1,inplace = True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9727         5  K1  A5   B1
#    9728         """
# -> 9729         return self._join_compat(
#    9730             other,
#    9731             on=on,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9766                     validate=validate,
#    9767                 )
# -> 9768             return merge(
#    9769                 self,
#    9770                 other,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     160         validate=validate,
#     161     )
# --> 162     return op.get_result(copy=copy)
#     163
#     164
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in get_result(self, copy)
#     809         join_index, left_indexer, right_indexer = self._get_join_info()
#     810
# --> 811         result = self._reindex_and_concat(
#     812             join_index, left_indexer, right_indexer, copy=copy
#     813         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in _reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     761         right = self.right[:]
#     762
# --> 763         llabels, rlabels = _items_overlap_with_suffix(
#     764             self.left._info_axis, self.right._info_axis, self.suffixes
#     765         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2602
#    2603     if not lsuffix and not rsuffix:
# -> 2604         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2605
#    2606     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['Embarked_C', 'Embarked_Q', 'Embarked_S'], dtype='object')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Embarked_SEmbarked_left  \
# 0      0         A/5 21171   7.2500  ...                    True
# 1      0          PC 17599  71.2833  ...                   False
# 2      0  STON/O2. 3101282   7.9250  ...                    True
# 3      0            113803  53.1000  ...                    True
# 4      0            373450   8.0500  ...                    True
#
#    Embarked_C_original  Embarked_Q_original  Embarked_S_original  \
# 0                False                False                 True
# 1                 True                False                False
# 2                False                False                 True
# 3                False                False                 True
# 4                False                False                 True
#
#    Embarked_C_dummy  Embarked_Q_dummy  Embarked_S_dummy  Embarked_C  \
# 0             False             False              True       False
# 1              True             False             False        True
# 2             False             False              True       False
# 3             False             False              True       False
# 4             False             False              True       False
#
#    Embarked_Q  Embarked_S
# 0       False        True
# 1       False       False
# 2       False        True
# 3       False        True
# 4       False        True
#
# [5 rows x 32 columns]

# %%
titanic.Sex = titanic.Sex.map({"male":0,"female":1})

# %%
y=titanic.Survived.copy()
X=titanic.drop(["Survived"],axis = 1)

# %%
X.drop(['Cabin','Ticket','Name','PassengerId'],axis=1,inplace=True)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pclass                    891 non-null    int64
#  1   Sex                       891 non-null    int64
#  2   Age                       714 non-null    float64
#  3   SibSp                     891 non-null    int64
#  4   Parch                     891 non-null    int64
#  5   Fare                      891 non-null    float64
#  6   Embarked_C_left           891 non-null    bool
#  7   Embarked_Q_left           891 non-null    bool
#  8   Embarked_S_left           891 non-null    bool
#  9   Embarked_C_right          891 non-null    bool
#  10  Embarked_Q_right          891 non-null    bool
#  11  Embarked_S_right          891 non-null    bool
#  12  Embarked_CEmbarked_right  891 non-null    bool
#  13  Embarked_QEmbarked_right  891 non-null    bool
#  14  Embarked_SEmbarked_right  891 non-null    bool
#  15  Embarked_CEmbarked_left   891 non-null    bool
#  16  Embarked_QEmbarked_left   891 non-null    bool
#  17  Embarked_SEmbarked_left   891 non-null    bool
#  18  Embarked_C_original       891 non-null    bool
#  19  Embarked_Q_original       891 non-null    bool
#  20  Embarked_S_original       891 non-null    bool
#  21  Embarked_C_dummy          891 non-null    bool
#  22  Embarked_Q_dummy          891 non-null    bool
#  23  Embarked_S_dummy          891 non-null    bool
#  24  Embarked_C                891 non-null    bool
#  25  Embarked_Q                891 non-null    bool
#  26  Embarked_S                891 non-null    bool
# dtypes: bool(21), float64(2), int64(4)
# memory usage: 60.2 KB

# %%
X.isnull().values.any()
# Out:
# True

# %%
X[pd.isnull(X).any(axis=1)]
# Out:
#      Pclass  Sex  Age  SibSp  Parch     Fare  Embarked_C_left  \
# 5         3    0  NaN      0      0   8.4583            False
# 17        2    0  NaN      0      0  13.0000            False
# 19        3    1  NaN      0      0   7.2250             True
# 26        3    0  NaN      0      0   7.2250             True
# 28        3    1  NaN      0      0   7.8792            False
# ..      ...  ...  ...    ...    ...      ...              ...
# 859       3    0  NaN      0      0   7.2292             True
# 863       3    1  NaN      8      2  69.5500            False
# 868       3    0  NaN      0      0   9.5000            False
# 878       3    0  NaN      0      0   7.8958            False
# 888       3    1  NaN      1      2  23.4500            False
#
#      Embarked_Q_left  Embarked_S_left  Embarked_C_right  ...  \
# 5               True            False             False  ...
# 17             False             True             False  ...
# 19             False            False              True  ...
# 26             False            False              True  ...
# 28              True            False             False  ...
# ..               ...              ...               ...  ...
# 859            False            False              True  ...
# 863            False             True             False  ...
# 868            False             True             False  ...
# 878            False             True             False  ...
# 888            False             True             False  ...
#
#      Embarked_SEmbarked_left  Embarked_C_original  Embarked_Q_original  \
# 5                      False                False                 True
# 17                      True                False                False
# 19                     False                 True                False
# 26                     False                 True                False
# 28                     False                False                 True
# ..                       ...                  ...                  ...
# 859                    False                 True                False
# 863                     True                False                False
# 868                     True                False                False
# 878                     True                False                False
# 888                     True                False                False
#
#      Embarked_S_original  Embarked_C_dummy  Embarked_Q_dummy  \
# 5                  False             False              True
# 17                  True             False             False
# 19                 False              True             False
# 26                 False              True             False
# 28                 False             False              True
# ..                   ...               ...               ...
# 859                False              True             False
# 863                 True             False             False
# 868                 True             False             False
# 878                 True             False             False
# 888                 True             False             False
#
#      Embarked_S_dummy  Embarked_C  Embarked_Q  Embarked_S
# 5               False       False        True       False
# 17               True       False       False        True
# 19              False        True       False       False
# 26              False        True       False       False
# 28              False       False        True       False
# ..                ...         ...         ...         ...
# 859             False        True       False       False
# 863              True       False       False        True
# 868              True       False       False        True
# 878              True       False       False        True
# 888              True       False       False        True
#
# [177 rows x 27 columns]

# %%
X.Age.fillna(X.Age.mean(),inplace=True)

# %%
X.isnull().values.any()
# Out:
# False

# %%
from sklearn.model_selection import train_test_split
X_train,X_valid,y_train,y_valid = train_test_split(X,y,test_size=0.2,random_state=7)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X_train,y_train)
# Out:
# 0.8103932584269663

# %%
model.score(X_valid,y_valid)
# Out:
# 0.7597765363128491
